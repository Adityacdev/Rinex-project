# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityacdev/Rinex-project/blob/main/main_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv('./daily_weather.csv')

# %%
data.columns
# Out:
# Index(['number', 'air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'relative_humidity_3pm', 'Unnamed: 11'],
#       dtype='object')

# %%
data.head()
# Out:
#    number  air_pressure_9am  ...  relative_humidity_3pm  Unnamed: 11
# 0       0        918.060000  ...              36.160000          NaN
# 1       1        917.347688  ...              19.426597          NaN
# 2       2        923.040000  ...              14.460000          NaN
# 3       3        920.502751  ...              12.742547          NaN
# 4       4        921.160000  ...              76.740000          NaN
#
# [5 rows x 12 columns]

# %%
data[data.isnull().any(axis=1)].head()
# Out:
#    number  air_pressure_9am  ...  relative_humidity_3pm  Unnamed: 11
# 0       0        918.060000  ...              36.160000          NaN
# 1       1        917.347688  ...              19.426597          NaN
# 2       2        923.040000  ...              14.460000          NaN
# 3       3        920.502751  ...              12.742547          NaN
# 4       4        921.160000  ...              76.740000          NaN
#
# [5 rows x 12 columns]

# %%
del data['number']

# %%
before_rows = data.shape[0]
print(before_rows)
# Out:
# 1095

# %%
data = data.dropna(how='all')

# %%
data = data.drop(columns=['Unnamed: 11']).dropna()

# %%
data.head()
# Out:
#    air_pressure_9am  air_temp_9am  ...  relative_humidity_9am  relative_humidity_3pm
# 0        918.060000     74.822000  ...              42.420000              36.160000
# 1        917.347688     71.403843  ...              24.328697              19.426597
# 2        923.040000     60.638000  ...               8.900000              14.460000
# 3        920.502751     70.138895  ...              12.189102              12.742547
# 4        921.160000     44.294000  ...              92.410000              76.740000
#
# [5 rows x 10 columns]

# %%
after_rows = data.shape[0]
print(after_rows)
# Out:
# 1064

# %%
before_rows - after_rows
# Out:
# 31

# %%
clean_data=data.copy()
clean_data['high_humidity_label'] = (clean_data['relative_humidity_3pm'] > 24.99)*1
clean_data['high_humidity_label'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: high_humidity_label, dtype: int64

# %%
y=clean_data[['high_humidity_label']].copy()
y.head()
# Out:
#    high_humidity_label
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['high_humidity_label'].plot(kind='hist', bins=20, title='high_humidity_label')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['high_humidity_label'].plot(kind='line', figsize=(8, 4), title='high_humidity_label')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
morning_features = ['air_pressure_9am','air_temp_9am','avg_wind_direction_9am','avg_wind_speed_9am',
        'max_wind_direction_9am','max_wind_speed_9am','rain_accumulation_9am',
        'rain_duration_9am','relative_humidity_9am']

# %%
x=clean_data[morning_features].copy()
x.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am'],
#       dtype='object')

# %%
y.columns
# Out:
# Index(['high_humidity_label'], dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=324)

# %%
humidity_classifer = DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)
humidity_classifer.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)

# %%
type(humidity_classifer)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
y_pred = humidity_classifer.predict(x_test)

# %%
y_pred[:10]
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 1, 1])

# %%
y_test['high_humidity_label'][:10]
# Out:
# 456     0
# 845     0
# 693     1
# 259     1
# 723     1
# 224     1
# 300     1
# 442     0
# 585     1
# 1057    1
# Name: high_humidity_label, dtype: int64

# %%
accuracy_score(y_true = y_test, y_pred = y_pred)*100
# Out:
# 90.05681818181817
